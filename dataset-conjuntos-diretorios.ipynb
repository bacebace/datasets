# %% [markdown]
# # Bibliotecas

# %%
from pathlib import Path
import os
import pandas as pd

import pickle

from sklearn.model_selection import train_test_split

import shutil

# %% [markdown]
# # Criar dataframe a partir do dataset

# %%
#dataset="/kaggle/input/garbage-v3-12-classes/garbage_classification_u"
dataset="/kaggle/input/garbage-classification/garbage_classification"
image_dir = Path(dataset)

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.JPG')) + list(image_dir.glob(r'**/*.jpg')) + list(image_dir.glob(r'**/*.png')) + list(image_dir.glob(r'**/*.png'))

labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# %%
image_df
# Out:
#                                                 Filepath        Label
# 0      /kaggle/input/garbage-classification/garbage_c...        metal
# 1      /kaggle/input/garbage-classification/garbage_c...        metal
# 2      /kaggle/input/garbage-classification/garbage_c...        metal
# 3      /kaggle/input/garbage-classification/garbage_c...        metal
# 4      /kaggle/input/garbage-classification/garbage_c...        metal
# ...                                                  ...          ...
# 15510  /kaggle/input/garbage-classification/garbage_c...  green-glass
# 15511  /kaggle/input/garbage-classification/garbage_c...  green-glass
# 15512  /kaggle/input/garbage-classification/garbage_c...  green-glass
# 15513  /kaggle/input/garbage-classification/garbage_c...  green-glass
# 15514  /kaggle/input/garbage-classification/garbage_c...  green-glass
#
# [15515 rows x 2 columns]

# %% [markdown]
# # Separar em conjuntos de treino e teste

# %%
train_df1, test_df = train_test_split(image_df, test_size=0.2, shuffle=True, random_state=42)

# %%
train_df1.shape
# Out:
# (12412, 2)

# %%
test_df.shape
# Out:
# (3103, 2)

# %% [markdown]
# # Criar o conjunto de validação a partir do conjunto de treino

# %%
train_df, val_df = train_test_split(train_df1, test_size=0.2, shuffle=True, random_state=42)

# %%
train_df.shape
# Out:
# (9929, 2)

# %%
val_df.shape
# Out:
# (2483, 2)

# %% [markdown]
# # Salvar os dataframes em arquivos binários

# %%
pickle.dump(train_df, open("/kaggle/working/train_df.pkl", 'wb'))
pickle.dump(val_df, open("/kaggle/working/val_df.pkl", 'wb'))
pickle.dump(test_df, open("/kaggle/working/test_df.pkl", 'wb'))

# %% [markdown]
# # Recuperar os dataframes a partir dos arquivos binários

# %% [markdown]
# Dado que a pessoa tem acesso ao dataset "garbage_classification", queremos que seja possível separá-lo sempre nos conjuntos de treino, validação e teste que criamos acima.
#
# Dessa forma, garantimos que nossos modelos sejam sempre treinados com o mesmo conjunto de treino, validados com o mesmo conjunto de validação e testados com o mesmo conjunto de teste.

# %%
train = pickle.load(open("/kaggle/input/garbage-classification-sets/train_df.pkl", 'rb'))
val = pickle.load(open("/kaggle/input/garbage-classification-sets/val_df.pkl", 'rb'))
test = pickle.load(open("/kaggle/input/garbage-classification-sets/test_df.pkl", 'rb'))

# %%
train.shape
# Out:
# (9929, 2)

# %%
val.shape
# Out:
# (2483, 2)

# %%
test.shape
# Out:
# (3103, 2)

# %% [markdown]
# # Alterar os endereços das imagens

# %% [markdown]
# Neste notebook, os endereços das imangens começam com:
#
# "/kaggle/input/garbage-classification"
#
# Porém, pode ser que no seu projeto o dataset esteja armazenado em outro endereço.
#
# Vamos ver como alterar os endereços no dataframe para adequá-los ao seu projeto local.
#
# Para exemplificar, o novo endereço deverá começar com "drive/MyDrive/CPQD", mas você pode substituí-lo com o que for necessário.

# %%
train
# Out:
#                                                 Filepath       Label
# 6891   /kaggle/input/garbage-classification/garbage_c...       shoes
# 11225  /kaggle/input/garbage-classification/garbage_c...     clothes
# 9241   /kaggle/input/garbage-classification/garbage_c...     clothes
# 13175  /kaggle/input/garbage-classification/garbage_c...     clothes
# 9170   /kaggle/input/garbage-classification/garbage_c...     clothes
# ...                                                  ...         ...
# 4642   /kaggle/input/garbage-classification/garbage_c...     battery
# 7072   /kaggle/input/garbage-classification/garbage_c...       shoes
# 2321   /kaggle/input/garbage-classification/garbage_c...  biological
# 73     /kaggle/input/garbage-classification/garbage_c...       metal
# 9447   /kaggle/input/garbage-classification/garbage_c...     clothes
#
# [9929 rows x 2 columns]

# %%
train['Filepath']=train.Filepath.str.replace("/kaggle/input/garbage-classification", "drive/MyDrive/CPQD")
val['Filepath']=val.Filepath.str.replace("/kaggle/input/garbage-classification", "drive/MyDrive/CPQD")
test['Filepath']=test.Filepath.str.replace("/kaggle/input/garbage-classification", "drive/MyDrive/CPQD")

# %%
train
# Out:
#                                                 Filepath       Label
# 6891   drive/MyDrive/CPQD/garbage_classification/shoe...       shoes
# 11225  drive/MyDrive/CPQD/garbage_classification/clot...     clothes
# 9241   drive/MyDrive/CPQD/garbage_classification/clot...     clothes
# 13175  drive/MyDrive/CPQD/garbage_classification/clot...     clothes
# 9170   drive/MyDrive/CPQD/garbage_classification/clot...     clothes
# ...                                                  ...         ...
# 4642   drive/MyDrive/CPQD/garbage_classification/batt...     battery
# 7072   drive/MyDrive/CPQD/garbage_classification/shoe...       shoes
# 2321   drive/MyDrive/CPQD/garbage_classification/biol...  biological
# 73     drive/MyDrive/CPQD/garbage_classification/meta...       metal
# 9447   drive/MyDrive/CPQD/garbage_classification/clot...     clothes
#
# [9929 rows x 2 columns]

# %%
val
# Out:
#                                                 Filepath       Label
# 5677   drive/MyDrive/CPQD/garbage_classification/tras...       trash
# 13923  drive/MyDrive/CPQD/garbage_classification/clot...     clothes
# 12266  drive/MyDrive/CPQD/garbage_classification/clot...     clothes
# 4358   drive/MyDrive/CPQD/garbage_classification/batt...     battery
# 1914   drive/MyDrive/CPQD/garbage_classification/biol...  biological
# ...                                                  ...         ...
# 9769   drive/MyDrive/CPQD/garbage_classification/clot...     clothes
# 10689  drive/MyDrive/CPQD/garbage_classification/clot...     clothes
# 7345   drive/MyDrive/CPQD/garbage_classification/shoe...       shoes
# 7483   drive/MyDrive/CPQD/garbage_classification/shoe...       shoes
# 11757  drive/MyDrive/CPQD/garbage_classification/clot...     clothes
#
# [2483 rows x 2 columns]

# %%
test
# Out:
#                                                 Filepath        Label
# 11755  drive/MyDrive/CPQD/garbage_classification/clot...      clothes
# 1011   drive/MyDrive/CPQD/garbage_classification/whit...  white-glass
# 8753   drive/MyDrive/CPQD/garbage_classification/clot...      clothes
# 3668   drive/MyDrive/CPQD/garbage_classification/brow...  brown-glass
# 12097  drive/MyDrive/CPQD/garbage_classification/clot...      clothes
# ...                                                  ...          ...
# 6436   drive/MyDrive/CPQD/garbage_classification/card...    cardboard
# 8072   drive/MyDrive/CPQD/garbage_classification/shoe...        shoes
# 5312   drive/MyDrive/CPQD/garbage_classification/tras...        trash
# 7729   drive/MyDrive/CPQD/garbage_classification/shoe...        shoes
# 5140   drive/MyDrive/CPQD/garbage_classification/tras...        trash
#
# [3103 rows x 2 columns]

# %% [markdown]
# # Criar diretórios para cada conjunto

# %%
os.mkdir("/kaggle/working/train")
os.mkdir("/kaggle/working/val")
os.mkdir("/kaggle/working/test")

# %% [markdown]
# # Copiar as imagens para seu respectivo diretório

# %% [markdown]
# * https://stackoverflow.com/questions/62397609/search-and-copy-files-listed-in-a-dataframe

# %%
train_path = Path("/kaggle/working/train")
val_path = Path("/kaggle/working/val")
test_path = Path("/kaggle/working/test")

# %%
for image in train_df.Filepath:
    shutil.copy(image, train_path)

# %%
for image in val_df.Filepath:
    shutil.copy(image, val_path)

# %%
for image in test_df.Filepath:
    shutil.copy(image, test_path)

# %% [markdown]
# # Salvar diretórios em arquivo compactado

# %%
# essa funcao estava criando .zip maiores que os proprios diretorios

#shutil.make_archive("/kaggle/working/train", 'zip', "/kaggle/working/")
#shutil.make_archive("/kaggle/working/val", 'zip', "/kaggle/working/")
#shutil.make_archive("/kaggle/working/test", 'zip', "/kaggle/working/")

# %%
# !zip -r output.zip /kaggle/working
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/train/ (stored 0%)
#   adding: kaggle/working/train/shoes472.jpg (deflated 1%)
#   adding: kaggle/working/train/brown-glass382.jpg (deflated 8%)
#   adding: kaggle/working/train/cardboard464.jpg (deflated 6%)
#   adding: kaggle/working/train/paper298.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes1723.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes2609.jpg (deflated 2%)
#   adding: kaggle/working/train/cardboard366.jpg (deflated 16%)
#   adding: kaggle/working/train/paper311.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes3738.jpg (deflated 1%)
#   adding: kaggle/working/train/paper1001.jpg (deflated 5%)
#   adding: kaggle/working/train/clothes3270.jpg (deflated 0%)
#   adding: kaggle/working/train/trash266.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes3168.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes1532.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes3392.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass630.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1444.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard137.jpg (deflated 2%)
#   adding: kaggle/working/train/cardboard514.jpg (deflated 8%)
#   adding: kaggle/working/train/shoes238.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes2959.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes589.jpg (deflated 3%)
#   adding: kaggle/working/train/trash585.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard77.jpg (deflated 1%)
#   adding: kaggle/working/train/biological219.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes1559.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1393.jpg (deflated 1%)
#   adding: kaggle/working/train/brown-glass422.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes627.jpg (deflated 1%)
#   adding: kaggle/working/train/paper918.jpg (deflated 0%)
#   adding: kaggle/working/train/white-glass3.jpg (deflated 5%)
#   adding: kaggle/working/train/shoes932.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes3728.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2498.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes761.jpg (deflated 4%)
#   adding: kaggle/working/train/clothes3433.jpg (deflated 1%)
#   adding: kaggle/working/train/plastic638.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes1529.jpg (deflated 1%)
#   adding: kaggle/working/train/battery170.jpg (deflated 4%)
#   adding: kaggle/working/train/brown-glass520.jpg (deflated 6%)
#   adding: kaggle/working/train/clothes2257.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard210.jpg (deflated 2%)
#   adding: kaggle/working/train/green-glass503.jpg (deflated 4%)
#   adding: kaggle/working/train/clothes2100.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4484.jpg (deflated 0%)
#   adding: kaggle/working/train/green-glass250.jpg (deflated 6%)
#   adding: kaggle/working/train/clothes4996.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3629.jpg (deflated 1%)
#   adding: kaggle/working/train/biological814.jpg (deflated 0%)
#   adding: kaggle/working/train/paper575.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1751.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes4892.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes954.jpg (deflated 6%)
#   adding: kaggle/working/train/cardboard606.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes1352.jpg (deflated 1%)
#   adding: kaggle/working/train/battery623.jpg (deflated 10%)
#   adding: kaggle/working/train/shoes881.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes693.jpg (deflated 1%)
#   adding: kaggle/working/train/metal739.jpg (deflated 4%)
#   adding: kaggle/working/train/cardboard94.jpg (deflated 2%)
#   adding: kaggle/working/train/cardboard54.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes1030.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes4719.jpg (deflated 0%)
#   adding: kaggle/working/train/trash52.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes2209.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes2896.jpg (deflated 4%)
#   adding: kaggle/working/train/clothes1426.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes965.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes2897.jpg (deflated 1%)
#   adding: kaggle/working/train/paper240.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes439.jpg (deflated 16%)
#   adding: kaggle/working/train/shoes379.jpg (deflated 5%)
#   adding: kaggle/working/train/white-glass723.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes1208.jpg (deflated 2%)
#   adding: kaggle/working/train/trash544.jpg (deflated 13%)
#   adding: kaggle/working/train/clothes4416.jpg (deflated 0%)
#   adding: kaggle/working/train/trash579.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3466.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1680.jpg (deflated 0%)
#   adding: kaggle/working/train/metal480.jpg (deflated 3%)
#   adding: kaggle/working/train/paper69.jpg (deflated 1%)
#   adding: kaggle/working/train/paper243.jpg (deflated 2%)
#   adding: kaggle/working/train/trash174.jpg (deflated 5%)
#   adding: kaggle/working/train/clothes5314.jpg (deflated 2%)
#   adding: kaggle/working/train/cardboard391.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass504.jpg (deflated 11%)
#   adding: kaggle/working/train/biological549.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes4239.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1877.jpg (deflated 0%)
#   adding: kaggle/working/train/trash645.jpg (deflated 6%)
#   adding: kaggle/working/train/clothes183.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard769.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes1253.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1458.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3236.jpg (deflated 0%)
#   adding: kaggle/working/train/brown-glass440.jpg (deflated 9%)
#   adding: kaggle/working/train/plastic38.jpg (deflated 2%)
#   adding: kaggle/working/train/trash1.jpg (deflated 0%)
#   adding: kaggle/working/train/green-glass629.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes1729.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes1337.jpg (deflated 2%)
#   adding: kaggle/working/train/white-glass350.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes3551.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2505.jpg (deflated 0%)
#   adding: kaggle/working/train/paper247.jpg (deflated 0%)
#   adding: kaggle/working/train/metal411.jpg (deflated 3%)
#   adding: kaggle/working/train/biological198.jpg (deflated 0%)
#   adding: kaggle/working/train/biological658.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes55.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3618.jpg (deflated 1%)
#   adding: kaggle/working/train/green-glass368.jpg (deflated 1%)
#   adding: kaggle/working/train/biological661.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4994.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes710.jpg (deflated 1%)
#   adding: kaggle/working/train/brown-glass358.jpg (stored 0%)
#   adding: kaggle/working/train/green-glass514.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes619.jpg (deflated 1%)
#   adding: kaggle/working/train/paper479.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes1721.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes1798.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes513.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes521.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2311.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3234.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1927.jpg (deflated 1%)
#   adding: kaggle/working/train/plastic536.jpg (deflated 5%)
#   adding: kaggle/working/train/clothes987.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes1882.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard664.jpg (deflated 13%)
#   adding: kaggle/working/train/white-glass245.jpg (deflated 3%)
#   adding: kaggle/working/train/shoes1241.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes3898.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard843.jpg (deflated 7%)
#   adding: kaggle/working/train/clothes687.jpg (deflated 0%)
#   adding: kaggle/working/train/plastic279.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass413.jpg (deflated 7%)
#   adding: kaggle/working/train/biological51.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes2806.jpg (deflated 0%)
#   adding: kaggle/working/train/white-glass521.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes3632.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes135.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes1025.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes3217.jpg (deflated 1%)
#   adding: kaggle/working/train/metal332.jpg (deflated 2%)
#   adding: kaggle/working/train/cardboard287.jpg (deflated 1%)
#   adding: kaggle/working/train/trash564.jpg (deflated 13%)
#   adding: kaggle/working/train/clothes373.jpg (deflated 1%)
#   adding: kaggle/working/train/brown-glass225.jpg (deflated 5%)
#   adding: kaggle/working/train/biological887.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes636.jpg (deflated 0%)
#   adding: kaggle/working/train/green-glass276.jpg (deflated 15%)
#   adding: kaggle/working/train/paper1029.jpg (deflated 0%)
#   adding: kaggle/working/train/white-glass552.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1525.jpg (deflated 0%)
#   adding: kaggle/working/train/metal462.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes1203.jpg (deflated 0%)
#   adding: kaggle/working/train/green-glass431.jpg (deflated 2%)
#   adding: kaggle/working/train/cardboard507.jpg (deflated 2%)
#   adding: kaggle/working/train/biological166.jpg (deflated 0%)
#   adding: kaggle/working/train/plastic162.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes1834.jpg (deflated 1%)
#   adding: kaggle/working/train/metal734.jpg (deflated 4%)
#   adding: kaggle/working/train/clothes324.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes499.jpg (deflated 1%)
#   adding: kaggle/working/train/brown-glass213.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes1167.jpg (deflated 1%)
#   adding: kaggle/working/train/trash505.jpg (deflated 1%)
#   adding: kaggle/working/train/paper323.jpg (deflated 0%)
#   adding: kaggle/working/train/paper402.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass325.jpg (deflated 11%)
#   adding: kaggle/working/train/brown-glass113.jpg (deflated 1%)
#   adding: kaggle/working/train/green-glass519.jpg (deflated 3%)
#   adding: kaggle/working/train/cardboard864.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes111.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard476.jpg (deflated 6%)
#   adding: kaggle/working/train/paper214.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes1699.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes362.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes906.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes2711.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass149.jpg (deflated 1%)
#   adding: kaggle/working/train/paper384.jpg (deflated 0%)
#   adding: kaggle/working/train/trash137.jpg (deflated 6%)
#   adding: kaggle/working/train/clothes5315.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes1450.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1880.jpg (deflated 0%)
#   adding: kaggle/working/train/white-glass596.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes1922.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4168.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass268.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes141.jpg (deflated 6%)
#   adding: kaggle/working/train/shoes159.jpg (deflated 4%)
#   adding: kaggle/working/train/biological277.jpg (deflated 0%)
#   adding: kaggle/working/train/plastic153.jpg (deflated 2%)
#   adding: kaggle/working/train/plastic147.jpg (deflated 2%)
#   adding: kaggle/working/train/biological595.jpg (deflated 8%)
#   adding: kaggle/working/train/shoes1550.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes1684.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes2606.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3223.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2732.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass164.jpg (deflated 2%)
#   adding: kaggle/working/train/plastic522.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes65.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2946.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1370.jpg (deflated 0%)
#   adding: kaggle/working/train/plastic475.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes3582.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard486.jpg (deflated 3%)
#   adding: kaggle/working/train/biological545.jpg (deflated 0%)
#   adding: kaggle/working/train/plastic278.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes5202.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes1232.jpg (deflated 0%)
#   adding: kaggle/working/train/plastic200.jpg (deflated 5%)
#   adding: kaggle/working/train/clothes253.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes753.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2910.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard845.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard111.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes1937.jpg (deflated 2%)
#   adding: kaggle/working/train/metal252.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes700.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes347.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes115.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes232.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1599.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3746.jpg (deflated 2%)
#   adding: kaggle/working/train/biological668.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes978.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes107.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes5227.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1470.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes36.jpg (deflated 10%)
#   adding: kaggle/working/train/clothes4302.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes1598.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3509.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes1358.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes5140.jpg (deflated 1%)
#   adding: kaggle/working/train/green-glass544.jpg (deflated 1%)
#   adding: kaggle/working/train/biological564.jpg (deflated 1%)
#   adding: kaggle/working/train/battery244.jpg (deflated 4%)
#   adding: kaggle/working/train/biological184.jpg (deflated 0%)
#   adding: kaggle/working/train/metal366.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes3342.jpg (deflated 0%)
#   adding: kaggle/working/train/battery342.jpg (deflated 8%)
#   adding: kaggle/working/train/battery429.jpg (deflated 1%)
#   adding: kaggle/working/train/biological836.jpg (deflated 0%)
#   adding: kaggle/working/train/brown-glass148.jpg (deflated 5%)
#   adding: kaggle/working/train/cardboard484.jpg (deflated 3%)
#   adding: kaggle/working/train/cardboard250.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard282.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes190.jpg (deflated 1%)
#   adding: kaggle/working/train/plastic625.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes5071.jpg (deflated 1%)
#   adding: kaggle/working/train/paper344.jpg (deflated 0%)
#   adding: kaggle/working/train/biological559.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes3421.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes418.jpg (deflated 0%)
#   adding: kaggle/working/train/battery765.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes464.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes489.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes417.jpg (deflated 0%)
#   adding: kaggle/working/train/white-glass286.jpg (deflated 3%)
#   adding: kaggle/working/train/white-glass100.jpg (deflated 4%)
#   adding: kaggle/working/train/metal98.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes578.jpg (deflated 1%)
#   adding: kaggle/working/train/brown-glass3.jpg (deflated 3%)
#   adding: kaggle/working/train/shoes1848.jpg (deflated 1%)
#   adding: kaggle/working/train/plastic415.jpg (deflated 8%)
#   adding: kaggle/working/train/clothes5237.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes4778.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1807.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes573.jpg (deflated 1%)
#   adding: kaggle/working/train/battery750.jpg (deflated 3%)
#   adding: kaggle/working/train/metal447.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes2826.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1010.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes694.jpg (deflated 0%)
#   adding: kaggle/working/train/biological740.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes5252.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3130.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard795.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes219.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes790.jpg (deflated 2%)
#   adding: kaggle/working/train/battery399.jpg (deflated 9%)
#   adding: kaggle/working/train/clothes3173.jpg (deflated 2%)
#   adding: kaggle/working/train/green-glass460.jpg (deflated 1%)
#   adding: kaggle/working/train/plastic823.jpg (deflated 12%)
#   adding: kaggle/working/train/paper541.jpg (deflated 0%)
#   adding: kaggle/working/train/paper709.jpg (deflated 0%)
#   adding: kaggle/working/train/paper98.jpg (deflated 5%)
#   adding: kaggle/working/train/clothes2924.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes1172.jpg (deflated 1%)
#   adding: kaggle/working/train/paper773.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes1106.jpg (deflated 1%)
#   adding: kaggle/working/train/battery551.jpg (deflated 3%)
#   adding: kaggle/working/train/paper258.jpg (deflated 0%)
#   adding: kaggle/working/train/white-glass265.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes2669.jpg (deflated 1%)
#   adding: kaggle/working/train/brown-glass119.jpg (deflated 6%)
#   adding: kaggle/working/train/clothes4643.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4846.jpg (deflated 1%)
#   adding: kaggle/working/train/plastic584.jpg (deflated 1%)
#   adding: kaggle/working/train/brown-glass414.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes3189.jpg (deflated 1%)
#   adding: kaggle/working/train/trash650.jpg (deflated 17%)
#   adding: kaggle/working/train/biological686.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes1500.jpg (deflated 2%)
#   adding: kaggle/working/train/green-glass429.jpg (deflated 1%)
#   adding: kaggle/working/train/paper898.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes1489.jpg (deflated 2%)
#   adding: kaggle/working/train/green-glass295.jpg (deflated 1%)
#   adding: kaggle/working/train/battery204.jpg (deflated 1%)
#   adding: kaggle/working/train/green-glass546.jpg (deflated 6%)
#   adding: kaggle/working/train/clothes3324.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard354.jpg (deflated 4%)
#   adding: kaggle/working/train/trash211.jpg (deflated 5%)
#   adding: kaggle/working/train/cardboard420.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2777.jpg (deflated 0%)
#   adding: kaggle/working/train/metal130.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes2607.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass461.jpg (deflated 1%)
#   adding: kaggle/working/train/battery214.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass269.jpg (deflated 7%)
#   adding: kaggle/working/train/trash547.jpg (stored 0%)
#   adding: kaggle/working/train/shoes255.jpg (deflated 9%)
#   adding: kaggle/working/train/clothes3878.jpg (deflated 3%)
#   adding: kaggle/working/train/cardboard218.jpg (deflated 2%)
#   adding: kaggle/working/train/white-glass396.jpg (deflated 8%)
#   adding: kaggle/working/train/clothes3827.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4051.jpg (deflated 1%)
#   adding: kaggle/working/train/trash19.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes168.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard431.jpg (deflated 5%)
#   adding: kaggle/working/train/green-glass74.jpg (deflated 3%)
#   adding: kaggle/working/train/white-glass51.jpg (deflated 4%)
#   adding: kaggle/working/train/biological224.jpg (deflated 2%)
#   adding: kaggle/working/train/biological888.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes4453.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes609.jpg (deflated 1%)
#   adding: kaggle/working/train/biological467.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard459.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes1223.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2467.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes5139.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1648.jpg (deflated 0%)
#   adding: kaggle/working/train/battery111.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes515.jpg (deflated 1%)
#   adding: kaggle/working/train/metal687.jpg (deflated 6%)
#   adding: kaggle/working/train/clothes3448.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1116.jpg (deflated 1%)
#   adding: kaggle/working/train/battery931.jpg (deflated 0%)
#   adding: kaggle/working/train/brown-glass535.jpg (deflated 0%)
#   adding: kaggle/working/train/white-glass26.jpg (deflated 3%)
#   adding: kaggle/working/train/paper48.jpg (deflated 1%)
#   adding: kaggle/working/train/paper150.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes1789.jpg (deflated 3%)
#   adding: kaggle/working/train/biological245.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1174.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3707.jpg (deflated 2%)
#   adding: kaggle/working/train/metal581.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes5273.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes1099.jpg (deflated 1%)
#   adding: kaggle/working/train/paper218.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1739.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes730.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1002.jpg (deflated 6%)
#   adding: kaggle/working/train/shoes539.jpg (deflated 6%)
#   adding: kaggle/working/train/shoes1696.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes388.jpg (deflated 0%)
#   adding: kaggle/working/train/biological256.jpg (deflated 0%)
#   adding: kaggle/working/train/metal49.jpg (deflated 3%)
#   adding: kaggle/working/train/shoes1746.jpg (deflated 0%)
#   adding: kaggle/working/train/battery332.jpg (deflated 18%)
#   adding: kaggle/working/train/biological527.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes3268.jpg (deflated 0%)
#   adding: kaggle/working/train/battery620.jpg (deflated 3%)
#   adding: kaggle/working/train/shoes365.jpg (deflated 3%)
#   adding: kaggle/working/train/biological879.jpg (deflated 0%)
#   adding: kaggle/working/train/battery394.jpg (deflated 7%)
#   adding: kaggle/working/train/brown-glass283.jpg (deflated 10%)
#   adding: kaggle/working/train/paper727.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes4572.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1519.jpg (deflated 0%)
#   adding: kaggle/working/train/plastic309.jpg (deflated 6%)
#   adding: kaggle/working/train/paper86.jpg (deflated 0%)
#   adding: kaggle/working/train/biological215.jpg (deflated 0%)
#   adding: kaggle/working/train/plastic6.jpg (deflated 1%)
#   adding: kaggle/working/train/battery743.jpg (deflated 3%)
#   adding: kaggle/working/train/plastic781.jpg (deflated 4%)
#   adding: kaggle/working/train/clothes664.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes18.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes758.jpg (deflated 1%)
#   adding: kaggle/working/train/paper226.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes4979.jpg (deflated 3%)
#   adding: kaggle/working/train/paper744.jpg (deflated 1%)
#   adding: kaggle/working/train/paper1031.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes1721.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes1547.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1708.jpg (deflated 4%)
#   adding: kaggle/working/train/shoes681.jpg (deflated 6%)
#   adding: kaggle/working/train/battery729.jpg (deflated 18%)
#   adding: kaggle/working/train/cardboard273.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes448.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes4231.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1226.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard699.jpg (deflated 3%)
#   adding: kaggle/working/train/metal704.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes1933.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes5203.jpg (deflated 3%)
#   adding: kaggle/working/train/metal59.jpg (deflated 4%)
#   adding: kaggle/working/train/plastic422.jpg (deflated 4%)
#   adding: kaggle/working/train/clothes3694.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2549.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes867.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes547.jpg (deflated 1%)
#   adding: kaggle/working/train/biological189.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes4858.jpg (deflated 1%)
#   adding: kaggle/working/train/metal685.jpg (deflated 4%)
#   adding: kaggle/working/train/shoes420.jpg (deflated 0%)
#   adding: kaggle/working/train/biological136.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes3151.jpg (deflated 0%)
#   adding: kaggle/working/train/metal502.jpg (deflated 5%)
#   adding: kaggle/working/train/clothes2223.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4165.jpg (deflated 0%)
#   adding: kaggle/working/train/battery116.jpg (deflated 1%)
#   adding: kaggle/working/train/trash257.jpg (deflated 9%)
#   adding: kaggle/working/train/clothes3093.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes77.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes710.jpg (deflated 1%)
#   adding: kaggle/working/train/biological452.jpg (deflated 0%)
#   adding: kaggle/working/train/cardboard237.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes1574.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1664.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1206.jpg (deflated 3%)
#   adding: kaggle/working/train/battery839.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes2689.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes534.jpg (deflated 2%)
#   adding: kaggle/working/train/battery490.jpg (deflated 7%)
#   adding: kaggle/working/train/clothes458.jpg (deflated 1%)
#   adding: kaggle/working/train/biological679.jpg (deflated 1%)
#   adding: kaggle/working/train/trash337.jpg (deflated 5%)
#   adding: kaggle/working/train/shoes233.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes3123.jpg (deflated 2%)
#   adding: kaggle/working/train/biological815.jpg (deflated 3%)
#   adding: kaggle/working/train/white-glass242.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes1161.jpg (deflated 1%)
#   adding: kaggle/working/train/trash59.jpg (deflated 3%)
#   adding: kaggle/working/train/brown-glass152.jpg (deflated 0%)
#   adding: kaggle/working/train/battery4.jpg (deflated 8%)
#   adding: kaggle/working/train/shoes377.jpg (deflated 2%)
#   adding: kaggle/working/train/cardboard739.jpg (deflated 2%)
#   adding: kaggle/working/train/paper561.jpg (deflated 0%)
#   adding: kaggle/working/train/metal223.jpg (deflated 9%)
#   adding: kaggle/working/train/clothes832.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3251.jpg (deflated 2%)
#   adding: kaggle/working/train/battery927.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4438.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4628.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4737.jpg (deflated 1%)
#   adding: kaggle/working/train/metal391.jpg (deflated 3%)
#   adding: kaggle/working/train/biological381.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3211.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4217.jpg (deflated 2%)
#   adding: kaggle/working/train/battery771.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1423.jpg (deflated 4%)
#   adding: kaggle/working/train/green-glass288.jpg (deflated 10%)
#   adding: kaggle/working/train/cardboard16.jpg (deflated 2%)
#   adding: kaggle/working/train/battery646.jpg (deflated 3%)
#   adding: kaggle/working/train/battery42.jpg (deflated 8%)
#   adding: kaggle/working/train/clothes4476.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes944.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes153.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass240.jpg (deflated 3%)
#   adding: kaggle/working/train/shoes1491.jpg (deflated 1%)
#   adding: kaggle/working/train/biological638.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes5125.jpg (deflated 1%)
#   adding: kaggle/working/train/trash98.jpg (deflated 3%)
#   adding: kaggle/working/train/battery288.jpg (deflated 7%)
#   adding: kaggle/working/train/clothes1357.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass573.jpg (deflated 6%)
#   adding: kaggle/working/train/clothes2487.jpg (deflated 2%)
#   adding: kaggle/working/train/paper990.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes2726.jpg (deflated 1%)
#   adding: kaggle/working/train/biological896.jpg (deflated 0%)
#   adding: kaggle/working/train/green-glass439.jpg (deflated 1%)
#   adding: kaggle/working/train/biological933.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2576.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes38.jpg (deflated 1%)
#   adding: kaggle/working/train/paper738.jpg (deflated 1%)
#   adding: kaggle/working/train/battery374.jpg (deflated 4%)
#   adding: kaggle/working/train/plastic42.jpg (deflated 1%)
#   adding: kaggle/working/train/biological745.jpg (deflated 0%)
#   adding: kaggle/working/train/paper863.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes249.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes342.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes603.jpg (deflated 1%)
#   adding: kaggle/working/train/paper970.jpg (deflated 5%)
#   adding: kaggle/working/train/green-glass277.jpg (deflated 2%)
#   adding: kaggle/working/train/biological685.jpg (deflated 1%)
#   adding: kaggle/working/train/battery555.jpg (deflated 7%)
#   adding: kaggle/working/train/brown-glass539.jpg (deflated 10%)
#   adding: kaggle/working/train/plastic734.jpg (deflated 7%)
#   adding: kaggle/working/train/clothes1609.jpg (deflated 0%)
#   adding: kaggle/working/train/cardboard747.jpg (deflated 2%)
#   adding: kaggle/working/train/cardboard625.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes3908.jpg (deflated 1%)
#   adding: kaggle/working/train/biological972.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes893.jpg (deflated 0%)
#   adding: kaggle/working/train/white-glass112.jpg (deflated 5%)
#   adding: kaggle/working/train/clothes1725.jpg (deflated 1%)
#   adding: kaggle/working/train/green-glass253.jpg (deflated 13%)
#   adding: kaggle/working/train/brown-glass588.jpg (deflated 8%)
#   adding: kaggle/working/train/paper754.jpg (deflated 2%)
#   adding: kaggle/working/train/trash461.jpg (deflated 5%)
#   adding: kaggle/working/train/green-glass603.jpg (deflated 0%)
#   adding: kaggle/working/train/paper312.jpg (deflated 0%)
#   adding: kaggle/working/train/battery562.jpg (deflated 9%)
#   adding: kaggle/working/train/trash434.jpg (deflated 8%)
#   adding: kaggle/working/train/biological768.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes5249.jpg (deflated 0%)
#   adding: kaggle/working/train/brown-glass494.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2905.jpg (deflated 1%)
#   adding: kaggle/working/train/battery147.jpg (deflated 2%)
#   adding: kaggle/working/train/white-glass173.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes2089.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes876.jpg (deflated 0%)
#   adding: kaggle/working/train/metal256.jpg (deflated 5%)
#   adding: kaggle/working/train/trash649.jpg (deflated 13%)
#   adding: kaggle/working/train/shoes1476.jpg (deflated 1%)
#   adding: kaggle/working/train/paper581.jpg (deflated 1%)
#   adding: kaggle/working/train/brown-glass424.jpg (deflated 1%)
#   adding: kaggle/working/train/metal642.jpg (deflated 1%)
#   adding: kaggle/working/train/green-glass465.jpg (deflated 9%)
#   adding: kaggle/working/train/trash316.jpg (deflated 11%)
#   adding: kaggle/working/train/green-glass435.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3767.jpg (deflated 1%)
#   adding: kaggle/working/train/battery350.jpg (deflated 10%)
#   adding: kaggle/working/train/paper749.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass509.jpg (deflated 7%)
#   adding: kaggle/working/train/plastic347.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes677.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes3644.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes657.jpg (deflated 10%)
#   adding: kaggle/working/train/clothes1435.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard708.jpg (deflated 2%)
#   adding: kaggle/working/train/brown-glass486.jpg (stored 0%)
#   adding: kaggle/working/train/clothes3441.jpg (deflated 2%)
#   adding: kaggle/working/train/metal651.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes1929.jpg (deflated 1%)
#   adding: kaggle/working/train/paper260.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes397.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes1862.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes882.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes1890.jpg (deflated 1%)
#   adding: kaggle/working/train/paper92.jpg (stored 0%)
#   adding: kaggle/working/train/clothes4192.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes774.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes611.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2346.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes122.jpg (deflated 8%)
#   adding: kaggle/working/train/plastic454.jpg (deflated 0%)
#   adding: kaggle/working/train/white-glass90.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes1850.jpg (deflated 1%)
#   adding: kaggle/working/train/metal511.jpg (deflated 1%)
#   adding: kaggle/working/train/paper144.jpg (deflated 0%)
#   adding: kaggle/working/train/biological201.jpg (deflated 0%)
#   adding: kaggle/working/train/paper155.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3363.jpg (deflated 1%)
#   adding: kaggle/working/train/biological257.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes4025.jpg (deflated 1%)
#   adding: kaggle/working/train/battery296.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes4246.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1929.jpg (deflated 1%)
#   adding: kaggle/working/train/paper565.jpg (deflated 2%)
#   adding: kaggle/working/train/trash219.jpg (deflated 5%)
#   adding: kaggle/working/train/metal155.jpg (deflated 11%)
#   adding: kaggle/working/train/biological232.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes41.jpg (deflated 13%)
#   adding: kaggle/working/train/clothes59.jpg (deflated 0%)
#   adding: kaggle/working/train/brown-glass385.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1160.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes29.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes2947.jpg (deflated 1%)
#   adding: kaggle/working/train/metal522.jpg (deflated 2%)
#   adding: kaggle/working/train/paper123.jpg (deflated 0%)
#   adding: kaggle/working/train/plastic394.jpg (deflated 2%)
#   adding: kaggle/working/train/paper232.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes75.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1451.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes937.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1399.jpg (deflated 1%)
#   adding: kaggle/working/train/plastic385.jpg (deflated 1%)
#   adding: kaggle/working/train/trash96.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes3389.jpg (deflated 1%)
#   adding: kaggle/working/train/battery514.jpg (deflated 0%)
#   adding: kaggle/working/train/biological817.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes1350.jpg (deflated 1%)
#   adding: kaggle/working/train/battery300.jpg (deflated 4%)
#   adding: kaggle/working/train/paper234.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes2658.jpg (deflated 1%)
#   adding: kaggle/working/train/trash522.jpg (deflated 12%)
#   adding: kaggle/working/train/green-glass596.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes910.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1272.jpg (deflated 0%)
#   adding: kaggle/working/train/white-glass711.jpg (deflated 7%)
#   adding: kaggle/working/train/shoes86.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1329.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes721.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard642.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes3518.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes1483.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2314.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1196.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4749.jpg (deflated 2%)
#   adding: kaggle/working/train/biological118.jpg (deflated 1%)
#   adding: kaggle/working/train/paper988.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3014.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2670.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard150.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3676.jpg (deflated 1%)
#   adding: kaggle/working/train/green-glass407.jpg (deflated 1%)
#   adding: kaggle/working/train/trash120.jpg (deflated 12%)
#   adding: kaggle/working/train/clothes3496.jpg (deflated 0%)
#   adding: kaggle/working/train/metal706.jpg (deflated 5%)
#   adding: kaggle/working/train/plastic587.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3204.jpg (deflated 1%)
#   adding: kaggle/working/train/metal344.jpg (deflated 3%)
#   adding: kaggle/working/train/shoes174.jpg (deflated 2%)
#   adding: kaggle/working/train/battery519.jpg (deflated 17%)
#   adding: kaggle/working/train/white-glass663.jpg (deflated 13%)
#   adding: kaggle/working/train/shoes979.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes4167.jpg (deflated 0%)
#   adding: kaggle/working/train/battery20.jpg (deflated 1%)
#   adding: kaggle/working/train/plastic632.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes1400.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes68.jpg (deflated 11%)
#   adding: kaggle/working/train/battery293.jpg (deflated 5%)
#   adding: kaggle/working/train/clothes1232.jpg (deflated 0%)
#   adding: kaggle/working/train/cardboard130.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes5256.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2046.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes193.jpg (deflated 3%)
#   adding: kaggle/working/train/shoes1011.jpg (deflated 5%)
#   adding: kaggle/working/train/shoes92.jpg (deflated 2%)
#   adding: kaggle/working/train/green-glass580.jpg (deflated 12%)
#   adding: kaggle/working/train/cardboard58.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1368.jpg (deflated 2%)
#   adding: kaggle/working/train/paper438.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4174.jpg (deflated 0%)
#   adding: kaggle/working/train/battery38.jpg (deflated 12%)
#   adding: kaggle/working/train/clothes1994.jpg (deflated 1%)
#   adding: kaggle/working/train/brown-glass441.jpg (deflated 3%)
#   adding: kaggle/working/train/shoes1499.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes3230.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes992.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass258.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes5006.jpg (deflated 0%)
#   adding: kaggle/working/train/metal406.jpg (deflated 1%)
#   adding: kaggle/working/train/metal242.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes3875.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes1784.jpg (deflated 1%)
#   adding: kaggle/working/train/metal50.jpg (deflated 2%)
#   adding: kaggle/working/train/brown-glass322.jpg (deflated 0%)
#   adding: kaggle/working/train/cardboard309.jpg (deflated 3%)
#   adding: kaggle/working/train/cardboard180.jpg (deflated 2%)
#   adding: kaggle/working/train/battery417.jpg (deflated 5%)
#   adding: kaggle/working/train/clothes5097.jpg (deflated 1%)
#   adding: kaggle/working/train/green-glass162.jpg (deflated 13%)
#   adding: kaggle/working/train/trash693.jpg (deflated 6%)
#   adding: kaggle/working/train/trash122.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes614.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes686.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes607.jpg (deflated 2%)
#   adding: kaggle/working/train/metal449.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes5286.jpg (deflated 0%)
#   adding: kaggle/working/train/battery376.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes2358.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes1057.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes701.jpg (deflated 0%)
#   adding: kaggle/working/train/biological159.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes5154.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes117.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes605.jpg (deflated 0%)
#   adding: kaggle/working/train/paper952.jpg (deflated 1%)
#   adding: kaggle/working/train/green-glass364.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes387.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4215.jpg (deflated 1%)
#   adding: kaggle/working/train/battery799.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass297.jpg (deflated 5%)
#   adding: kaggle/working/train/brown-glass157.jpg (deflated 3%)
#   adding: kaggle/working/train/brown-glass500.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes743.jpg (deflated 12%)
#   adding: kaggle/working/train/paper481.jpg (deflated 1%)
#   adding: kaggle/working/train/metal38.jpg (deflated 2%)
#   adding: kaggle/working/train/battery725.jpg (deflated 5%)
#   adding: kaggle/working/train/clothes2081.jpg (deflated 0%)
#   adding: kaggle/working/train/battery842.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes1136.jpg (deflated 4%)
#   adding: kaggle/working/train/biological274.jpg (deflated 0%)
#   adding: kaggle/working/train/paper167.jpg (deflated 0%)
#   adding: kaggle/working/train/paper522.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes4197.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes163.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard516.jpg (deflated 5%)
#   adding: kaggle/working/train/white-glass261.jpg (deflated 11%)
#   adding: kaggle/working/train/plastic344.jpg (deflated 3%)
#   adding: kaggle/working/train/biological907.jpg (deflated 3%)
#   adding: kaggle/working/train/brown-glass115.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes1257.jpg (deflated 1%)
#   adding: kaggle/working/train/battery648.jpg (deflated 12%)
#   adding: kaggle/working/train/paper804.jpg (deflated 3%)
#   adding: kaggle/working/train/shoes1821.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard522.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes1549.jpg (deflated 2%)
#   adding: kaggle/working/train/paper62.jpg (deflated 0%)
#   adding: kaggle/working/train/white-glass43.jpg (deflated 2%)
#   adding: kaggle/working/train/paper591.jpg (deflated 3%)
#   adding: kaggle/working/train/cardboard617.jpg (deflated 8%)
#   adding: kaggle/working/train/green-glass36.jpg (deflated 0%)
#   adding: kaggle/working/train/shoes1170.jpg (deflated 2%)
#   adding: kaggle/working/train/white-glass218.jpg (deflated 3%)
#   adding: kaggle/working/train/green-glass574.jpg (deflated 9%)
#   adding: kaggle/working/train/battery322.jpg (deflated 4%)
#   adding: kaggle/working/train/trash616.jpg (deflated 8%)
#   adding: kaggle/working/train/clothes8.jpg (deflated 2%)
#   adding: kaggle/working/train/cardboard406.jpg (deflated 9%)
#   adding: kaggle/working/train/biological716.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard562.jpg (deflated 7%)
#   adding: kaggle/working/train/shoes1909.jpg (deflated 7%)
#   adding: kaggle/working/train/white-glass145.jpg (deflated 1%)
#   adding: kaggle/working/train/biological874.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes2895.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass338.jpg (deflated 10%)
#   adding: kaggle/working/train/battery548.jpg (deflated 5%)
#   adding: kaggle/working/train/clothes4414.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4009.jpg (deflated 1%)
#   adding: kaggle/working/train/paper644.jpg (deflated 7%)
#   adding: kaggle/working/train/green-glass60.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes243.jpg (deflated 1%)
#   adding: kaggle/working/train/green-glass22.jpg (deflated 1%)
#   adding: kaggle/working/train/brown-glass43.jpg (deflated 4%)
#   adding: kaggle/working/train/clothes538.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes2481.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes10.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4540.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4242.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes3698.jpg (deflated 3%)
#   adding: kaggle/working/train/cardboard767.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes1997.jpg (deflated 0%)
#   adding: kaggle/working/train/metal504.jpg (deflated 2%)
#   adding: kaggle/working/train/metal403.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes5275.jpg (deflated 1%)
#   adding: kaggle/working/train/plastic364.jpg (deflated 10%)
#   adding: kaggle/working/train/shoes1665.jpg (deflated 1%)
#   adding: kaggle/working/train/trash673.jpg (deflated 0%)
#   adding: kaggle/working/train/brown-glass239.jpg (deflated 3%)
#   adding: kaggle/working/train/biological934.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes498.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes3227.jpg (deflated 1%)
#   adding: kaggle/working/train/plastic754.jpg (deflated 4%)
#   adding: kaggle/working/train/clothes834.jpg (deflated 1%)
#   adding: kaggle/working/train/metal288.jpg (deflated 2%)
#   adding: kaggle/working/train/metal370.jpg (deflated 2%)
#   adding: kaggle/working/train/trash490.jpg (deflated 9%)
#   adding: kaggle/working/train/biological258.jpg (deflated 0%)
#   adding: kaggle/working/train/clothes1544.jpg (deflated 0%)
#   adding: kaggle/working/train/plastic143.jpg (deflated 3%)
#   adding: kaggle/working/train/clothes4917.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes2423.jpg (deflated 1%)
#   adding: kaggle/working/train/cardboard294.jpg (deflated 2%)
#   adding: kaggle/working/train/shoes1125.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes953.jpg (deflated 1%)
#   adding: kaggle/working/train/plastic60.jpg (deflated 4%)
#   adding: kaggle/working/train/shoes1793.jpg (deflated 1%)
#   adding: kaggle/working/train/clothes4893.jpg (deflated 0%)
#   adding: kaggle/working/train/biological352.jpg (deflated 1%)
#   adding: kaggle/working/train/white-glass373.jpg (deflated 3%)
#   adding: kaggle/working/train/cardboard838.jpg (deflated 2%)
#   adding: kaggle/working/train/paper80.jpg (deflated 0%)
#   adding: kaggle/working/train/battery587.jpg (deflated 5%)
#   adding: kaggle/working/train/shoes491.jpg (deflated 3%)
#   adding: kaggle/working/train/metal62.jpg (deflated 1%)
#   adding: kaggle/working/train/battery323.jpg (deflated 3%)
#   adding: kaggle/working/train/green-glass536.jpg (deflated 8%)
#   adding: kaggle/working/train/shoes1292.jpg (deflated 2%)
#   adding: kaggle/working/train/clothes3876.jpg (deflated 1%)
#   adding: kaggle/working/train/shoes805.jpg (deflated 6%)
#   adding: kaggle/working/train/battery804.jpg (deflated 0%)
#   adding: kaggle/working/train/cardboard276.jpg (deflated 1%)
#   adding: kaggle/working/train/metal745.jpg (deflated 1%)
# ...
#   adding: kaggle/working/test/biological275.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes3960.jpg (deflated 2%)
#   adding: kaggle/working/test/battery193.jpg (deflated 3%)
#   adding: kaggle/working/test/trash345.jpg (deflated 3%)
#   adding: kaggle/working/test/shoes808.jpg (deflated 7%)
#   adding: kaggle/working/test/biological622.jpg (deflated 0%)
#   adding: kaggle/working/test/battery744.jpg (deflated 13%)
#   adding: kaggle/working/test/clothes3686.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes1808.jpg (deflated 2%)
#   adding: kaggle/working/test/biological462.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes821.jpg (deflated 0%)
#   adding: kaggle/working/test/battery53.jpg (deflated 7%)
#   adding: kaggle/working/test/battery944.jpg (deflated 0%)
#   adding: kaggle/working/test/metal474.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes5186.jpg (deflated 1%)
#   adding: kaggle/working/test/paper299.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes2102.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes3337.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes4758.jpg (deflated 2%)
#   adding: kaggle/working/test/clothes2017.jpg (deflated 1%)
#   adding: kaggle/working/test/white-glass735.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes3682.jpg (deflated 3%)
#   adding: kaggle/working/test/battery627.jpg (deflated 5%)
#   adding: kaggle/working/test/biological889.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes2585.jpg (deflated 1%)
#   adding: kaggle/working/test/trash527.jpg (deflated 5%)
#   adding: kaggle/working/test/paper870.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes242.jpg (deflated 1%)
#   adding: kaggle/working/test/green-glass520.jpg (deflated 0%)
#   adding: kaggle/working/test/biological535.jpg (deflated 0%)
#   adding: kaggle/working/test/brown-glass558.jpg (deflated 5%)
#   adding: kaggle/working/test/white-glass253.jpg (deflated 9%)
#   adding: kaggle/working/test/brown-glass509.jpg (deflated 6%)
#   adding: kaggle/working/test/brown-glass397.jpg (deflated 6%)
#   adding: kaggle/working/test/biological241.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes3241.jpg (deflated 1%)
#   adding: kaggle/working/test/shoes124.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes5084.jpg (deflated 1%)
#   adding: kaggle/working/test/cardboard52.jpg (deflated 2%)
#   adding: kaggle/working/test/plastic263.jpg (deflated 5%)
#   adding: kaggle/working/test/clothes5159.jpg (deflated 1%)
#   adding: kaggle/working/test/metal468.jpg (deflated 1%)
#   adding: kaggle/working/test/shoes1888.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes4061.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes4113.jpg (deflated 0%)
#   adding: kaggle/working/test/shoes1688.jpg (deflated 4%)
#   adding: kaggle/working/test/clothes1202.jpg (deflated 0%)
#   adding: kaggle/working/test/white-glass187.jpg (deflated 3%)
#   adding: kaggle/working/test/battery73.jpg (deflated 4%)
#   adding: kaggle/working/test/brown-glass590.jpg (deflated 2%)
#   adding: kaggle/working/test/clothes4683.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes4355.jpg (deflated 1%)
#   adding: kaggle/working/test/shoes1020.jpg (deflated 0%)
#   adding: kaggle/working/test/trash217.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes2269.jpg (deflated 1%)
#   adding: kaggle/working/test/biological113.jpg (deflated 0%)
#   adding: kaggle/working/test/cardboard842.jpg (deflated 1%)
#   adding: kaggle/working/test/brown-glass352.jpg (deflated 7%)
#   adding: kaggle/working/test/clothes479.jpg (deflated 1%)
#   adding: kaggle/working/test/metal163.jpg (deflated 1%)
#   adding: kaggle/working/test/shoes158.jpg (deflated 0%)
#   adding: kaggle/working/test/white-glass225.jpg (deflated 5%)
#   adding: kaggle/working/test/plastic707.jpg (deflated 0%)
#   adding: kaggle/working/test/white-glass608.jpg (deflated 12%)
#   adding: kaggle/working/test/clothes2648.jpg (deflated 1%)
#   adding: kaggle/working/test/cardboard869.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes991.jpg (deflated 1%)
#   adding: kaggle/working/test/cardboard820.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes3524.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes4170.jpg (deflated 1%)
#   adding: kaggle/working/test/white-glass549.jpg (deflated 8%)
#   adding: kaggle/working/test/clothes204.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes3891.jpg (deflated 1%)
#   adding: kaggle/working/test/brown-glass570.jpg (deflated 10%)
#   adding: kaggle/working/test/white-glass426.jpg (deflated 10%)
#   adding: kaggle/working/test/clothes3756.jpg (deflated 1%)
#   adding: kaggle/working/test/shoes1634.jpg (deflated 0%)
#   adding: kaggle/working/test/biological878.jpg (deflated 0%)
#   adding: kaggle/working/test/metal200.jpg (deflated 1%)
#   adding: kaggle/working/test/white-glass386.jpg (deflated 9%)
#   adding: kaggle/working/test/battery914.jpg (deflated 2%)
#   adding: kaggle/working/test/brown-glass142.jpg (deflated 1%)
#   adding: kaggle/working/test/battery446.jpg (deflated 4%)
#   adding: kaggle/working/test/brown-glass121.jpg (deflated 2%)
#   adding: kaggle/working/test/trash566.jpg (deflated 6%)
#   adding: kaggle/working/test/clothes3858.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes4371.jpg (deflated 2%)
#   adding: kaggle/working/test/battery97.jpg (deflated 3%)
#   adding: kaggle/working/test/paper510.jpg (deflated 4%)
#   adding: kaggle/working/test/clothes775.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes401.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes1008.jpg (deflated 1%)
#   adding: kaggle/working/test/brown-glass98.jpg (deflated 10%)
#   adding: kaggle/working/test/metal240.jpg (deflated 2%)
#   adding: kaggle/working/test/trash320.jpg (deflated 10%)
#   adding: kaggle/working/test/plastic119.jpg (deflated 2%)
#   adding: kaggle/working/test/shoes1442.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes3918.jpg (deflated 1%)
#   adding: kaggle/working/test/cardboard711.jpg (deflated 9%)
#   adding: kaggle/working/test/trash127.jpg (deflated 12%)
#   adding: kaggle/working/test/metal28.jpg (deflated 1%)
#   adding: kaggle/working/test/trash407.jpg (deflated 10%)
#   adding: kaggle/working/test/cardboard458.jpg (deflated 2%)
#   adding: kaggle/working/test/biological17.jpg (deflated 0%)
#   adding: kaggle/working/test/shoes746.jpg (stored 0%)
#   adding: kaggle/working/test/biological865.jpg (deflated 0%)
#   adding: kaggle/working/test/plastic140.jpg (deflated 17%)
#   adding: kaggle/working/test/battery409.jpg (deflated 17%)
#   adding: kaggle/working/test/biological131.jpg (deflated 5%)
#   adding: kaggle/working/test/clothes997.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes4934.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes4423.jpg (deflated 1%)
#   adding: kaggle/working/test/biological932.jpg (deflated 0%)
#   adding: kaggle/working/test/shoes1414.jpg (deflated 6%)
#   adding: kaggle/working/test/cardboard733.jpg (deflated 6%)
#   adding: kaggle/working/test/plastic485.jpg (deflated 2%)
#   adding: kaggle/working/test/paper793.jpg (deflated 7%)
#   adding: kaggle/working/test/battery283.jpg (deflated 4%)
#   adding: kaggle/working/test/clothes1320.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes569.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes207.jpg (deflated 1%)
#   adding: kaggle/working/test/metal221.jpg (deflated 2%)
#   adding: kaggle/working/test/clothes227.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes262.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes2886.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes4515.jpg (deflated 1%)
#   adding: kaggle/working/test/biological386.jpg (deflated 0%)
#   adding: kaggle/working/test/shoes483.jpg (deflated 6%)
#   adding: kaggle/working/test/white-glass158.jpg (deflated 2%)
#   adding: kaggle/working/test/clothes3311.jpg (deflated 1%)
#   adding: kaggle/working/test/battery723.jpg (deflated 7%)
#   adding: kaggle/working/test/clothes3165.jpg (deflated 0%)
#   adding: kaggle/working/test/plastic757.jpg (deflated 5%)
#   adding: kaggle/working/test/cardboard630.jpg (deflated 6%)
#   adding: kaggle/working/test/clothes4181.jpg (deflated 0%)
#   adding: kaggle/working/test/shoes1120.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes2871.jpg (deflated 1%)
#   adding: kaggle/working/test/cardboard181.jpg (deflated 3%)
#   adding: kaggle/working/test/paper74.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes4163.jpg (deflated 1%)
#   adding: kaggle/working/test/cardboard650.jpg (deflated 2%)
#   adding: kaggle/working/test/clothes264.jpg (deflated 2%)
#   adding: kaggle/working/test/biological172.jpg (deflated 3%)
#   adding: kaggle/working/test/clothes1296.jpg (deflated 0%)
#   adding: kaggle/working/test/battery543.jpg (deflated 1%)
#   adding: kaggle/working/test/battery284.jpg (deflated 4%)
#   adding: kaggle/working/test/clothes2150.jpg (deflated 1%)
#   adding: kaggle/working/test/battery98.jpg (deflated 4%)
#   adding: kaggle/working/test/battery938.jpg (deflated 4%)
#   adding: kaggle/working/test/brown-glass1.jpg (deflated 3%)
#   adding: kaggle/working/test/shoes635.jpg (deflated 2%)
#   adding: kaggle/working/test/clothes4495.jpg (deflated 1%)
#   adding: kaggle/working/test/shoes609.jpg (deflated 1%)
#   adding: kaggle/working/test/metal385.jpg (deflated 2%)
#   adding: kaggle/working/test/biological273.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes4262.jpg (deflated 0%)
#   adding: kaggle/working/test/white-glass167.jpg (deflated 3%)
#   adding: kaggle/working/test/cardboard152.jpg (deflated 1%)
#   adding: kaggle/working/test/white-glass466.jpg (deflated 3%)
#   adding: kaggle/working/test/white-glass139.jpg (deflated 1%)
#   adding: kaggle/working/test/paper881.jpg (deflated 1%)
#   adding: kaggle/working/test/white-glass743.jpg (deflated 4%)
#   adding: kaggle/working/test/clothes2084.jpg (deflated 1%)
#   adding: kaggle/working/test/plastic768.jpg (deflated 7%)
#   adding: kaggle/working/test/clothes1833.jpg (deflated 1%)
#   adding: kaggle/working/test/white-glass674.jpg (deflated 19%)
#   adding: kaggle/working/test/shoes1177.jpg (deflated 4%)
#   adding: kaggle/working/test/trash593.jpg (stored 0%)
#   adding: kaggle/working/test/clothes660.jpg (deflated 1%)
#   adding: kaggle/working/test/cardboard66.jpg (deflated 3%)
#   adding: kaggle/working/test/paper655.jpg (deflated 6%)
#   adding: kaggle/working/test/clothes2870.jpg (deflated 1%)
#   adding: kaggle/working/test/battery742.jpg (deflated 4%)
#   adding: kaggle/working/test/shoes1009.jpg (deflated 2%)
#   adding: kaggle/working/test/clothes3487.jpg (deflated 1%)
#   adding: kaggle/working/test/white-glass579.jpg (deflated 3%)
#   adding: kaggle/working/test/shoes1652.jpg (deflated 0%)
#   adding: kaggle/working/test/green-glass82.jpg (deflated 5%)
#   adding: kaggle/working/test/brown-glass269.jpg (deflated 3%)
#   adding: kaggle/working/test/plastic109.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes1470.jpg (deflated 1%)
#   adding: kaggle/working/test/green-glass158.jpg (deflated 5%)
#   adding: kaggle/working/test/clothes4219.jpg (deflated 0%)
#   adding: kaggle/working/test/paper619.jpg (deflated 0%)
#   adding: kaggle/working/test/shoes1597.jpg (deflated 0%)
#   adding: kaggle/working/test/paper654.jpg (deflated 2%)
#   adding: kaggle/working/test/clothes4323.jpg (deflated 1%)
#   adding: kaggle/working/test/metal275.jpg (deflated 3%)
#   adding: kaggle/working/test/clothes3296.jpg (deflated 1%)
#   adding: kaggle/working/test/paper690.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes276.jpg (deflated 0%)
#   adding: kaggle/working/test/plastic567.jpg (deflated 5%)
#   adding: kaggle/working/test/white-glass334.jpg (deflated 2%)
#   adding: kaggle/working/test/clothes4768.jpg (deflated 1%)
#   adding: kaggle/working/test/trash192.jpg (deflated 0%)
#   adding: kaggle/working/test/shoes157.jpg (deflated 5%)
#   adding: kaggle/working/test/brown-glass400.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes3743.jpg (deflated 1%)
#   adding: kaggle/working/test/plastic236.jpg (deflated 1%)
#   adding: kaggle/working/test/brown-glass581.jpg (deflated 9%)
#   adding: kaggle/working/test/battery479.jpg (deflated 8%)
#   adding: kaggle/working/test/cardboard511.jpg (deflated 5%)
#   adding: kaggle/working/test/shoes1301.jpg (deflated 0%)
#   adding: kaggle/working/test/plastic93.jpg (deflated 1%)
#   adding: kaggle/working/test/battery513.jpg (deflated 6%)
#   adding: kaggle/working/test/clothes3556.jpg (deflated 1%)
#   adding: kaggle/working/test/paper409.jpg (deflated 0%)
#   adding: kaggle/working/test/green-glass233.jpg (deflated 0%)
#   adding: kaggle/working/test/metal451.jpg (deflated 5%)
#   adding: kaggle/working/test/clothes3319.jpg (deflated 1%)
#   adding: kaggle/working/test/shoes593.jpg (deflated 0%)
#   adding: kaggle/working/test/plastic577.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes3962.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes2171.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes1794.jpg (deflated 1%)
#   adding: kaggle/working/test/trash536.jpg (deflated 11%)
#   adding: kaggle/working/test/clothes1848.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes1300.jpg (deflated 1%)
#   adding: kaggle/working/test/paper962.jpg (deflated 0%)
#   adding: kaggle/working/test/shoes765.jpg (deflated 1%)
#   adding: kaggle/working/test/trash236.jpg (deflated 1%)
#   adding: kaggle/working/test/biological677.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes3548.jpg (deflated 1%)
#   adding: kaggle/working/test/plastic111.jpg (deflated 3%)
#   adding: kaggle/working/test/battery613.jpg (deflated 2%)
#   adding: kaggle/working/test/clothes803.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes4888.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes3449.jpg (deflated 1%)
#   adding: kaggle/working/test/paper698.jpg (deflated 1%)
#   adding: kaggle/working/test/shoes445.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes4012.jpg (deflated 1%)
#   adding: kaggle/working/test/battery654.jpg (deflated 2%)
#   adding: kaggle/working/test/clothes4801.jpg (deflated 1%)
#   adding: kaggle/working/test/green-glass388.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes4309.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes856.jpg (deflated 1%)
#   adding: kaggle/working/test/shoes306.jpg (deflated 8%)
#   adding: kaggle/working/test/clothes5214.jpg (deflated 2%)
#   adding: kaggle/working/test/clothes1780.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes886.jpg (deflated 0%)
#   adding: kaggle/working/test/cardboard682.jpg (deflated 2%)
#   adding: kaggle/working/test/metal740.jpg (deflated 3%)
#   adding: kaggle/working/test/cardboard860.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes4169.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes426.jpg (deflated 1%)
#   adding: kaggle/working/test/paper118.jpg (deflated 0%)
#   adding: kaggle/working/test/battery535.jpg (deflated 4%)
#   adding: kaggle/working/test/shoes841.jpg (deflated 2%)
#   adding: kaggle/working/test/clothes208.jpg (deflated 2%)
#   adding: kaggle/working/test/battery176.jpg (deflated 2%)
#   adding: kaggle/working/test/plastic338.jpg (deflated 7%)
#   adding: kaggle/working/test/clothes4760.jpg (deflated 1%)
#   adding: kaggle/working/test/white-glass388.jpg (deflated 8%)
#   adding: kaggle/working/test/white-glass709.jpg (deflated 13%)
#   adding: kaggle/working/test/plastic124.jpg (deflated 4%)
#   adding: kaggle/working/test/biological337.jpg (deflated 4%)
#   adding: kaggle/working/test/clothes1484.jpg (deflated 0%)
#   adding: kaggle/working/test/clothes3869.jpg (deflated 2%)
#   adding: kaggle/working/test/clothes1054.jpg (deflated 1%)
#   adding: kaggle/working/test/metal101.jpg (deflated 0%)
#   adding: kaggle/working/test/biological485.jpg (deflated 1%)
#   adding: kaggle/working/test/clothes4605.jpg (deflated 1%)
#   adding: kaggle/working/test/green-glass550.jpg (deflated 2%)
#   adding: kaggle/working/test/battery438.jpg (deflated 3%)
#   adding: kaggle/working/test/clothes3922.jpg (deflated 0%)
#   adding: kaggle/working/test/shoes1657.jpg (deflated 0%)
#   adding: kaggle/working/test/battery431.jpg (deflated 7%)
#   adding: kaggle/working/test/paper974.jpg (deflated 0%)
